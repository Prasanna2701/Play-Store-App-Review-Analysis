# %% [markdown]
# <div style="background-color: #f4f4f4; padding: 10px;">
#     <img src="https://i.ytimg.com/vi/i0cZyazgpk8/maxresdefault.jpg" style="width: 100%;">
# </div>

# %% [markdown]
# **Android currently dominates the mobile operating system landscape, powering approximately 90% of all mobile devices. Central to this ecosystem is the Google Play Store, the largest and most popular Android app marketplace. Our project aimed to collect and analyze detailed information on apps available in the Google Play Store to provide insights into app features and the current state of the Android app market. This data has immense potential to drive app-making businesses toward success by offering actionable insights for developers to leverage and capture a significant share of the Android market. Each app entry in the dataset includes values for category, rating, size, and more. Additionally, we have another dataset containing customer reviews of these Android apps. By exploring and analyzing this data, we aim to uncover key factors that contribute to app engagement and success.**

# %% [markdown]
# **Project Type**    - EDA
#
# **Contribution**    - Individual

# %% [markdown]
# The notebook aims to analyze over ten thousand apps from the Google Play Store to develop pricing strategies.
#
# The dataset includes two files:
#
# 1. **Play Store Data.csv**: Contains detailed information about each app on the Google Play Store, with 13 features describing each app.
# 2. **user_reviews.csv**: Contains 100 reviews for each app, ranked by their contribution to sentiment analysis. Each review has been pre-processed and assigned three additional features: Sentiment (Positive, Negative, or Neutral), Sentiment Polarity, and Sentiment Subjectivity.

# %% [markdown]
# **Steps for analyzing Google Play Store apps data:**
#
# 1. **Import Libraries**:
#    - Load the necessary libraries for data analysis and visualization.
#
# 2. **Load the Data**:
#    - Import the dataset containing Google Play Store apps information.
#
# 3. **Data Description**:
#    - Provide an overview and description of the dataset, including column names and data types.
#
# 4. **Data Cleaning**:
#    - Clean the dataset by handling missing values, correcting data types, and removing duplicates.
#
# 5. **Top 10 Highest Rated Apps by Category**:
#    - Identify and list the top 10 highest-rated apps in each category.
#
# 6. **Number of Applications per Category**:
#    - Count and display the number of applications available in each category.
#
# 7. **Top 10 Most Downloaded Apps**:
#    - Determine and list the top 10 apps with the highest number of downloads.
#
# 8. **Highest and Lowest Rated 'FAMILY' Category Apps**:
#    - Find and list the 10 apps with the highest and lowest ratings in the 'FAMILY' category.
#
# 9. **Free vs Paid Apps**:
#    - Analyze and compare the number of free and paid apps in the dataset.
#
# 10. **Relation Between App Category and Price**:
#     - Explore the relationship between app categories and their prices.
#
# 11. **Filter Out Junk Apps**:
#     - Identify and remove any "junk" apps from the dataset based on specific criteria.
#
# 12. **Sentiment Analysis of User Reviews**:
#     - Perform sentiment analysis on user reviews to understand user satisfaction and feedback.

# %% [markdown]
# #**Project Name - Play Store App Reviews Analysis**#

# %% [markdown]
# **NAME : PRASANNA DAULATKAR**

# %% [markdown]
# #**Github link**#

# %% [markdown]
# PRASANNA DAULATKAR  -
# https://github.com/Prasanna2701/Play-Store-App-Review-Analysis

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# In this project, our aim was to gather and analyze detailed information on apps in the Google Play Store to provide insights into app features and the current state of the Android app market.
#
# We utilized libraries such as Pandas, NumPy, Matplotlib, and Seaborn to perform data cleaning and visualization.
#
# Thousands of new applications are regularly uploaded to the Google Play Store, with a vast number of independent developers working on designing successful apps. Given the intense global competition, it is crucial for developers to know if they are on the right track. Since most Play Store applications are free, the revenue model, including in-app purchases, advertisements, and subscriptions, is often obscure and not readily available. Therefore, an app's success is typically determined by the number of installations and user ratings it has received over its lifetime, rather than the revenue generated. The goal of this study is to deliver insights that help understand customer demands better, thus aiding developers in popularizing their products.
#
# We have sought to uncover relationships among various attributes, such as whether an application is free or paid, user reviews, and app ratings.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Explore and analyze the data to identify key factors responsible for app engagement and success.
#
# Two datasets are provided: one containing basic app information (play_store_data.csv) and the other containing user reviews (user_reviews.csv). We need to examine and evaluate both datasets to determine the critical characteristics that influence app engagement and success.

# %% [markdown]
# # **Business Objective**

# %% [markdown]
# Analyze user app preferences according to categories, genres, installations, sizes, types, etc., to assist developers in determining the appropriate dimensions for their apps.

# %% [markdown]
# #**Importing the libraries**#

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
import seaborn as sns

# %% [markdown]
# #**Load the play store data**#

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
#loading the play store data
df = pd.read_csv('drive/MyDrive/Capstone Project/Play store analysis/Play Store Data.csv')

# %% [markdown]
# #**Main Dataset**#

# %% [markdown]
# This dataset comprises information about applications available on Google Play. It includes 10,841 rows of data with the following columns:
#
# - **App Category**: The category under which the app falls, such as beauty, business, entertainment, or education.
# - **Rating**: The user-assigned rating of the app on a scale of 1 to 5.
# - **Reviews**: The count of user reviews received by each app.
# - **Size**: The amount of memory required for installing the application.
# - **Installs**: The number of times the application has been installed by users.
# - **Type**: Indicates whether the app is free or paid.
# - **Price**: The cost of the app if it's not free.
# - **Content Rating**: Specifies the target audience for the app, such as teens, mature audiences, or everyone.
# - **Genres**: Sub-category for each app, providing more specific information within the main category (e.g., Education: Pretend Play).
# - **Last Updated**: Date of the latest update released for the app.
# - **Current Ver**: The current version of the app.
# - **Android Ver**: The earliest version of the Android operating system supported by the app.

# %% [markdown]
# #**Load the user review data**#

# %%
#load the user review data
df2= pd.read_csv('drive/MyDrive/Capstone Project/Play store analysis/User Reviews.csv')

# %% [markdown]
# #**Sentiment Analysis**#

# %% [markdown]
# This dataset comprises 64,295 rows of information detailing app names, reviews, and sentiment analysis results. The columns include:
#
# - **App**: Name of the application.
# - **Translated_Review**: The review text, either in English or translated from another language.
# - **Sentiment**: The sentiment classification of the review, categorized as Positive, Neutral, or Negative.
# - **Sentiment_Polarity**: A numerical score indicating the degree of positivity or negativity in the sentiment, ranging from -1 (most negative) to 1 (most positive).
# - **Sentiment_Subjectivity**: A score from 0 to 1 representing the subjectivity of the review. Lower values imply factual content, while higher values suggest opinions or judgments.

# %% [markdown]
# #**Descripton of Data1**#

# %%
#Detailed information of the play store data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
#Describe the whole play store data
df.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
#Check, how many null value in each column
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
#View the top 5 rows
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
#View last 5 rows
df.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# ...

# %% [markdown]
# #**Description of data 2**#

# %%
#Detailed information of the user review data
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     64295 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37432 non-null  object
#  3   Sentiment_Polarity      37432 non-null  float64
#  4   Sentiment_Subjectivity  37432 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 2.5+ MB

# %%
#Describe the whole user review data
df2.describe()
# Out:
#        Sentiment_Polarity  Sentiment_Subjectivity
# count        37432.000000            37432.000000
# mean             0.182146                0.492704
# std              0.351301                0.259949
# min             -1.000000                0.000000
# 25%              0.000000                0.357143
# 50%              0.150000                0.514286
# 75%              0.400000                0.650000
# max              1.000000                1.000000

# %%
#Check, how many null value in each column
df2.isnull().sum()
# Out:
# App                           0
# Translated_Review         26868
# Sentiment                 26863
# Sentiment_Polarity        26863
# Sentiment_Subjectivity    26863
# dtype: int64

# %%
#View the top 5 rows
df2.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %%
#View the last 5 rows
df2.tail()
# Out:
#                                App Translated_Review Sentiment  \
# 64290  Houzz Interior Design Ideas               NaN       NaN
# 64291  Houzz Interior Design Ideas               NaN       NaN
# 64292  Houzz Interior Design Ideas               NaN       NaN
# 64293  Houzz Interior Design Ideas               NaN       NaN
# 64294  Houzz Interior Design Ideas               NaN       NaN
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 64290                 NaN                     NaN
# 64291                 NaN                     NaN
# 64292                 NaN                     NaN
# 64293                 NaN                     NaN
# 64294                 NaN                     NaN

# %% [markdown]
# #**Cleaning the Data Frame 1**#
# **CONVERT TO NUMERAL DATA**

# %%
#check the unique element in reviews column
df['Reviews'].unique()
# Out:
# array(['159', '967', '87510', ..., '603', '1195', '398307'], dtype=object)

# %%
df['Reviews'] = pd.to_numeric(df['Reviews'],errors='coerce')

# %% [markdown]
# errors=’coerce’. It will replace all non-numeric values with NaN.

# %% [markdown]
# **Fix the Size**

# %%
df['Size'].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
# ...

# %%
def fix_size(s):
  try:
    if s.endswith('M'):
      return float(s[:-1])
    elif s.endswith('k'):
      return (float(s[:-1]) / 1024)
    elif s == '1,000+':
      return 1.0
    else:
      return np.nan
  except:
      return np.nan

# %% [markdown]
# **Demo**

# %%
fix_size('98M')
# Out:
# 98.0

# %% [markdown]
# 1 mb =1024kb

# %%
fix_size('45k')
# Out:
# 0.0439453125

# %%
fix_size('demo')
# Out:
# nan

# %% [markdown]
# **Fix the  all elements in Size columns**

# %%
df['Size']= df['Size'].apply(fix_size)

# %%
df['Size'].unique()
# Out:
# array([1.90000000e+01, 1.40000000e+01, 8.70000000e+00, 2.50000000e+01,
#        2.80000000e+00, 5.60000000e+00, 2.90000000e+01, 3.30000000e+01,
#        3.10000000e+00, 2.80000000e+01, 1.20000000e+01, 2.00000000e+01,
#        2.10000000e+01, 3.70000000e+01, 2.70000000e+00, 5.50000000e+00,
#        1.70000000e+01, 3.90000000e+01, 3.10000000e+01, 4.20000000e+00,
#        7.00000000e+00, 2.30000000e+01, 6.00000000e+00, 6.10000000e+00,
#        4.60000000e+00, 9.20000000e+00, 5.20000000e+00, 1.10000000e+01,
#        2.40000000e+01,            nan, 9.40000000e+00, 1.50000000e+01,
#        1.00000000e+01, 1.20000000e+00, 2.60000000e+01, 8.00000000e+00,
#        7.90000000e+00, 5.60000000e+01, 5.70000000e+01, 3.50000000e+01,
#        5.40000000e+01, 1.96289062e-01, 3.60000000e+00, 5.70000000e+00,
#        8.60000000e+00, 2.40000000e+00, 2.70000000e+01, 2.50000000e+00,
#        1.60000000e+01, 3.40000000e+00, 8.90000000e+00, 3.90000000e+00,
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10840 non-null  float64
#  4   Size            9146 non-null   float64
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(3), object(10)
# memory usage: 1.1+ MB

# %%
df['Price'].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
# ...

# %%
def fix_Price(A):
  try:
    if A.startswith('$'):
      return float(A[1:])
    else:
      return 0.0
  except:
    return np.nan

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10840 non-null  float64
#  4   Size            9146 non-null   float64
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(3), object(10)
# memory usage: 1.1+ MB

# %%
df['Price']=df['Price'].apply(fix_Price)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10840 non-null  float64
#  4   Size            9146 non-null   float64
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(4), object(9)
# memory usage: 1.1+ MB

# %%
df['Price'].unique()
# Out:
# array([  0.  ,   4.99,   3.99,   6.99,   1.49,   2.99,   7.99,   5.99,
#          3.49,   1.99,   9.99,   7.49,   0.99,   9.  ,   5.49,  10.  ,
#         24.99,  11.99,  79.99,  16.99,  14.99,   1.  ,  29.99,  12.99,
#          2.49,  10.99,   1.5 ,  19.99,  15.99,  33.99,  74.99,  39.99,
#          3.95,   4.49,   1.7 ,   8.99,   2.  ,   3.88,  25.99, 399.99,
#         17.99, 400.  ,   3.02,   1.76,   4.84,   4.77,   1.61,   2.5 ,
#          1.59,   6.49,   1.29,   5.  ,  13.99, 299.99, 379.99,  37.99,
#         18.99, 389.99,  19.9 ,   8.49,   1.75,  14.  ,   4.85,  46.99,
#        109.99, 154.99,   3.08,   2.59,   4.8 ,   1.96,  19.4 ,   3.9 ,
#          4.59,  15.46,   3.04,   4.29,   2.6 ,   3.28,   4.6 ,  28.99,
#          2.95,   2.9 ,   1.97, 200.  ,  89.99,   2.56,  30.99,   3.61,
#        394.99,   1.26,   1.2 ,   1.04])

# %%
df['Rating'].unique()
# Out:
# array([ 4.1,  3.9,  4.7,  4.5,  4.3,  4.4,  3.8,  4.2,  4.6,  3.2,  4. ,
#         nan,  4.8,  4.9,  3.6,  3.7,  3.3,  3.4,  3.5,  3.1,  5. ,  2.6,
#         3. ,  1.9,  2.5,  2.8,  2.7,  1. ,  2.9,  2.3,  2.2,  1.7,  2. ,
#         1.8,  2.4,  1.6,  2.1,  1.4,  1.5,  1.2, 19. ])

# %%
fx = df[df['Rating']>5].index
fx
# Out:
# Index([10472], dtype='int64')

# %%
df.drop(fx,axis =0,inplace =True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10840 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  float64
#  4   Size            9145 non-null   float64
#  5   Installs        10840 non-null  object
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(4), object(9)
# memory usage: 1.2+ MB

# %%
df['Category'].unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION'],
#       dtype=object)

# %%
def lower_category(B):
  return B.title()

# %%
lower_category('AUTO_AND_VEHICLES')
# Out:
# 'Auto_And_Vehicles'

# %%
df['Category'] =df['Category'].apply(lower_category)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10840 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  float64
#  4   Size            9145 non-null   float64
#  5   Installs        10840 non-null  object
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(4), object(9)
# memory usage: 1.2+ MB

# %%
df['Installs'].unique()
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '50+', '100+', '500+',
#        '10+', '1+', '5+', '0+', '0'], dtype=object)

# %%
df['Installs'] = df.Installs.str.replace(",","")
df['Installs'] = df.Installs.str.replace("+","")
df['Installs'] = df['Installs'].astype(float)
df['Installs'].dtype
# Out:
# dtype('float64')

# %%
df['Installs'].unique()
# Out:
# array([1.e+04, 5.e+05, 5.e+06, 5.e+07, 1.e+05, 5.e+04, 1.e+06, 1.e+07,
#        5.e+03, 1.e+08, 1.e+09, 1.e+03, 5.e+08, 5.e+01, 1.e+02, 5.e+02,
#        1.e+01, 1.e+00, 5.e+00, 0.e+00])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10840 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10840 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10840 non-null  float64
#  4   Size            9145 non-null   float64
#  5   Installs        10840 non-null  float64
#  6   Type            10839 non-null  object
#  7   Price           10840 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10840 non-null  object
#  10  Last Updated    10840 non-null  object
#  11  Current Ver     10832 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(5), object(8)
# memory usage: 1.2+ MB

# %%
df['Android Ver'].unique()
# Out:
# array(['4.0.3 and up', '4.2 and up', '4.4 and up', '2.3 and up',
#        '3.0 and up', '4.1 and up', '4.0 and up', '2.3.3 and up',
#        'Varies with device', '2.2 and up', '5.0 and up', '6.0 and up',
#        '1.6 and up', '1.5 and up', '2.1 and up', '7.0 and up',
#        '5.1 and up', '4.3 and up', '4.0.3 - 7.1.1', '2.0 and up',
#        '3.2 and up', '4.4W and up', '7.1 and up', '7.0 - 7.1.1',
#        '8.0 and up', '5.0 - 8.0', '3.1 and up', '2.0.1 and up',
#        '4.1 - 7.1.1', nan, '5.0 - 6.0', '1.0 and up', '2.2 - 7.1.1',
#        '5.0 - 7.1.1'], dtype=object)

# %%
def correction(y):
  try:
    if y == 'Varies with device':
      return np.nan
    elif y == '4.4W and up':
      return y.replace('W','')
    else:
      return y
  except:
      return y

# %%
df['Android Ver'] = df['Android Ver'].apply(correction)

# %%
df['Android Ver'].unique()
# Out:
# array(['4.0.3 and up', '4.2 and up', '4.4 and up', '2.3 and up',
#        '3.0 and up', '4.1 and up', '4.0 and up', '2.3.3 and up', nan,
#        '2.2 and up', '5.0 and up', '6.0 and up', '1.6 and up',
#        '1.5 and up', '2.1 and up', '7.0 and up', '5.1 and up',
#        '4.3 and up', '4.0.3 - 7.1.1', '2.0 and up', '3.2 and up',
#        '7.1 and up', '7.0 - 7.1.1', '8.0 and up', '5.0 - 8.0',
#        '3.1 and up', '2.0.1 and up', '4.1 - 7.1.1', '5.0 - 6.0',
#        '1.0 and up', '2.2 - 7.1.1', '5.0 - 7.1.1'], dtype=object)

# %% [markdown]
# #**Top 10 Highest rating Apps in google play store in terms of categories**#

# %%
cp=df.sort_values(['Rating'],ascending=False)
Highest_Rating_App= cp.loc[:,['App','Category','Rating']]
Highest_Rating_App.head(11)
# Out:
#                               App            Category  Rating
# 9056  Santa's Monster Shootout DX                Game     5.0
# 8395                        DG TV  News_And_Magazines     5.0
# 8493          PK and DK Audio App              Family     5.0
# 6330    HON. B.J. ACS COLLEGE ALE              Family     5.0
# 6342                     BJ Foods            Business     5.0
# 6363          Read it easy for BK           Lifestyle     5.0
# 9766                    ER Assist        Productivity     5.0
# 6364              BK Video Status              Family     5.0
# 6372        BK Formula Calculator               Tools     5.0
# 6375            Dr Bk Sachin bhai           Lifestyle     5.0
# 9806         Dr. ES PV Calculator               Tools     5.0

# %% [markdown]
# #**Number of Application in terms of Category**#

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(15, 8))
sns.countplot(x='Category', data=df)
plt.title('Number of Apps Per Category')
plt.xticks(rotation=80)
plt.ylabel('Number of Apps')
plt.show()

# %% [markdown]
# #**Top 10 apps which  has more downloads**#

# %%
bm = df.sort_values('Installs',ascending=False)
More_downloads_App= bm.loc[:,['App','Installs']]
More_downloads_App.head(11)
# Out:
#                                            App      Installs
# 3896                            Subway Surfers  1.000000e+09
# 3943                                  Facebook  1.000000e+09
# 335   Messenger – Text and Video Chat for Free  1.000000e+09
# 3523                              Google Drive  1.000000e+09
# 3565                              Google Drive  1.000000e+09
# 2884                             Google Photos  1.000000e+09
# 3665                                   YouTube  1.000000e+09
# 2853                             Google Photos  1.000000e+09
# 4234             Skype - free IM & video calls  1.000000e+09
# 3687                   Google Play Movies & TV  1.000000e+09
# 2808                             Google Photos  1.000000e+09

# %% [markdown]
# #**Which 10 apps from the 'FAMILY' category are having the lowest rating and highest rating**#

# %% [markdown]
# **lowest rating**

# %%
ab = df[df['Category'] == 'Family']
bv = ab.sort_values(by=['Rating'], ascending=True)

Family_lowest_rating= bv.loc[:,['Category','Rating']]
Family_lowest_rating.head(11)
# Out:
#       Category  Rating
# 5978    Family     1.0
# 10324   Family     1.0
# 4127    Family     1.0
# 4905    Family     1.6
# 6135    Family     1.7
# 9176    Family     1.7
# 6812    Family     1.8
# 4904    Family     1.8
# 9890    Family     1.9
# 7416    Family     1.9
# 6532    Family     1.9

# %% [markdown]
# **Highest rating**

# %%
hi = df[df['Category'] == 'Family']
hig = hi.sort_values(by=['Rating'], ascending=False)

Family_highest_rating = hig.loc[:,['Category','Rating']]
Family_highest_rating.head(11)
# Out:
#       Category  Rating
# 10837   Family     5.0
# 9531    Family     5.0
# 7320    Family     5.0
# 7307    Family     5.0
# 7239    Family     5.0
# 5246    Family     5.0
# 9496    Family     5.0
# 9503    Family     5.0
# 7212    Family     5.0
# 7204    Family     5.0
# 9511    Family     5.0

# %% [markdown]
# #**FREE AND PAID APPS**#

# %%
plt.figure(figsize=(10, 5))
sns.countplot(df['Type'])
plt.title('Type Distribution')
plt.ylabel('Number of Apps')
plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# #**Relation between app category and app price**#

# %%
fig, ax = plt.subplots()
fig.set_size_inches(15, 8)

popular_app_cats = df[df.Category.isin(['Game', 'Family', 'Photography',
                                            'Medical', 'Tools', 'Finance',
                                            'Lifestyle','Business'])]

ax = sns.stripplot(x = popular_app_cats["Price"], y = popular_app_cats["Category"], jitter=True, linewidth=1)
ax.set_title('App Price Distribution by Category') # Add a title here
plt.show()

# %% [markdown]
# #**Sentiment analysis of user reviews**#

# %%
merged_df = pd.merge(df, df2, on = "App")
merged_df.head(3)
# Out:
#                    App        Category  Rating  Reviews  Size  Installs  Type  \
# 0  Coloring book moana  Art_And_Design     3.9    967.0  14.0  500000.0  Free
# 1  Coloring book moana  Art_And_Design     3.9    967.0  14.0  500000.0  Free
# 2  Coloring book moana  Art_And_Design     3.9    967.0  14.0  500000.0  Free
#
#    Price Content Rating                     Genres      Last Updated  \
# 0    0.0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 1    0.0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 2    0.0       Everyone  Art & Design;Pretend Play  January 15, 2018
#
#   Current Ver   Android Ver  \
# 0       2.0.0  4.0.3 and up
# 1       2.0.0  4.0.3 and up
# 2       2.0.0  4.0.3 and up
#
#                                    Translated_Review Sentiment  \
# 0  A kid's excessive ads. The types ads allowed a...  Negative
# 1                                         It bad >:(  Negative
# ...

# %%
sns.set_style('ticks')
fig, ax = plt.subplots()
fig.set_size_inches(11, 8)

ax = sns.boxplot(x = 'Type', y = 'Sentiment_Polarity', data = merged_df)
ax.set_title('Sentiment Polarity Distribution')
# Out:
# Text(0.5, 1.0, 'Sentiment Polarity Distribution')

# %% [markdown]
# #**Filter out "junk" apps**#

# %%
apps_under_100 = popular_app_cats[popular_app_cats["Price"]<100]

fig, ax = plt.subplots()
fig.set_size_inches(15, 8)

ax = sns.stripplot(x = "Price", y ="Category", data = apps_under_100, jitter = True, linewidth = 1)
ax.set_title('App pricing trend across categories after filtering for junk apps')
# Out:
# Text(0.5, 1.0, 'App pricing trend across categories after filtering for junk apps')

# %% [markdown]
# #**correlation**#

# %%
# Select only numerical columns before calculating correlation
numerical_df = df.select_dtypes(include=['float', 'int'])
correlation_matrix = numerical_df.corr()
print(correlation_matrix)
# Out:
#             Rating   Reviews      Size  Installs     Price
# Rating    1.000000  0.068141  0.083737  0.051355 -0.021903
# Reviews   0.068141  1.000000  0.238214  0.643122 -0.009667
# Size      0.083737  0.238214  1.000000  0.164787 -0.023007
# Installs  0.051355  0.643122  0.164787  1.000000 -0.011689
# Price    -0.021903 -0.009667 -0.023007 -0.011689  1.000000

# %%
# Select only numerical columns before calculating correlation
numerical_df = df.select_dtypes(include=['float', 'int'])

fig, axes = plt.subplots(figsize=(8, 8))
sns.heatmap(numerical_df.corr(), ax=axes, annot=True, linewidths=0.1, fmt='.2f', square=True)
plt.show()

# %% [markdown]
# #**Solution of Business Objective**#

# %% [markdown]
# Based on the analysis, the FAMILY category shows significant potential as it appeals to all age groups. The GAME category also demonstrates considerable scope.
#
# Although apps in the FAMILY, SOCIAL, COMMUNICATION, and ENTERTAINMENT categories have the highest number of installs, ratings, and reviews, reflecting current trends among Android users, they do not appear in the top 5 most expensive app categories on the store, which are primarily FINANCE and LIFESTYLE. In conclusion, the prevailing trend in the Android market centers around apps that provide assistance, facilitate communication, or offer entertainment.

# %% [markdown]
# #**Conclusion**#

# %% [markdown]
# After analyzing the dataset, we've uncovered some intriguing and significant facts that any Android user would find fascinating:
#
# a) Top 10 highest-rated apps on the Google Play Store by category.
#
# b) Number of applications in each category.
#
# c) Top 10 apps with the most downloads.
#
# d) Top 10 and bottom 10 rated apps in the 'FAMILY' category.
#
# e) Breakdown of free versus paid apps.
#
# f) Relationship between app category and app price.
#
# The Google Play Store Apps report offers valuable insights into app trends on the platform. According to the visualizations, the most popular apps (in terms of user installs) are predominantly from categories like GAME, COMMUNICATION, and TOOL, despite these categories having fewer apps compared to the FAMILY category. This trend is likely because apps in these categories are designed to entertain or assist users. Additionally, it suggests that developers in these categories prioritize quality over quantity.
#
# Furthermore, the charts indicate that most apps with ratings above 4.0 also have a high number of reviews and user installs. While there are some outliers regarding size and price, these do not suggest that high-rated apps are generally larger or more expensive, as these spikes are likely due to a small number of exceptions. Moreover, the categories SOCIAL and GAME, including apps like Instagram and Clash of Clans, tend to have the highest number of reviews.
